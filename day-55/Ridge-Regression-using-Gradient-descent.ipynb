# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
import numpy as np

# %%
X,y = load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor(penalty='l2',max_iter=500,eta0=0.1,learning_rate='constant',alpha=0.001)

# %%
sgd.fit(X_train,y_train)
# Out:
# SGDRegressor(alpha=0.001, eta0=0.1, learning_rate='constant', max_iter=500)

# %%
y_pred = sgd.predict(X_test)

# %%
print("R2_Score : ",r2_score(y_test,y_pred))
print("Coefficient : ",sgd.coef_)
print("Intercept : ",sgd.intercept_)
# Out:
# R2_Score :  0.3464235675913744
# Coefficient :  [  53.29915652 -163.24664571  372.16459086  274.15888069   -6.69729931
#   -58.25056945 -170.20284417  140.9049849   334.98362811   95.23920895]
# Intercept :  [131.38624895]

# %%
class RRModel_Gradient_Descent:
    def __init__(self,epochs,learning_rate,alpha):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.alpha = alpha
        self.coef_ = None
        self.intercept_ = None

    def fit(self,X_train,y_train):
        self.coef_ = np.ones(X_train.shape[1])
        self.intercept_ = 0
        thetha = np.insert(self.coef_,0,self.intercept_)

        X_train = np.insert(X_train,0,1,axis=1)

        for i in range(self.epochs):
            thetha_der = np.dot(X_train.T,X_train).dot(thetha) - np.dot(X_train.T,y_train) + self.alpha*thetha
            thetha = thetha - self.learning_rate*thetha_der

        self.coef_ = thetha[1:]
        self.intercept_ = thetha[0]

    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
rrm = RRModel_Gradient_Descent(epochs=500,alpha=0.001,learning_rate=0.005)

# %%
rrm.fit(X_train,y_train)

# %%
y_pred = rrm.predict(X_test)

# %%
print("R2_Score : ",r2_score(y_test,y_pred))
print("Coefficient : ",rrm.coef_)
print("Intercept : ",rrm.intercept_)
# Out:
# R2_Score :  0.4738018280260913
# Coefficient :  [  46.65050914 -221.3750037   452.12080647  325.54248128  -29.09464178
#   -96.47517735 -190.90017011  146.32900372  400.80267299   95.09048094]
# Intercept :  150.86975316713472
