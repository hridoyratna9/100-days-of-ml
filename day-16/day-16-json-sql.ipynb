# %%
import pandas as pd

# %% [markdown]
# ### Working with json

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# ### Working with sql

# %%
pip install mysql.connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql.connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip list -o
# Out:
# Package                           Version            Latest              Type
# --------------------------------- ------------------ ------------------- -----
# aiobotocore                       2.12.3             2.23.0              wheel
# aiohappyeyeballs                  2.4.0              2.6.1               wheel
# aiohttp                           3.10.5             3.12.13             wheel
# aioitertools                      0.7.1              0.12.0              wheel
# aiosignal                         1.2.0              1.3.2               wheel
# alabaster                         0.7.16             1.0.0               wheel
# altair                            5.0.1              5.5.0               wheel
# anaconda-client                   1.12.3             1.13.0              wheel
# anaconda-cloud-auth               0.5.1              0.7.2               wheel
# annotated-types                   0.6.0              0.7.0               wheel
# ...

# %%
import mysql.connector

# %%
mysql.connector.connect(host='localhost',user='root',password='',database='world')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 mysql.connector.connect(host='localhost',user='root',password='',database='world')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# ...

# %%
pip install --user mysql-connector-python

# %%
pip show mysql-connector-python

# %%
import mysql.connector
print(mysql.connector.__version__)
# Out:
# 9.3.0

# %%
pip install mysql.connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
mysql.connector.connect(host='localhost',user='root',password='',database='world')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mysql.connector.connect(host='localhost',user='root',password='',database='world')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\pooling.py:323, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:185, in MySQLConnection.__init__(self, **kwargs)
#     183 if kwargs:
#     184     try:
# --> 185         self.connect(**kwargs)
#     186     except Exception:
#     187         # Tidy-up underlying socket on failure
#     188         self.close()
#
# ...

# %%
import mysql.connector

db = mysql.connector.connect(
    host='localhost',
    user='root',
    password='hridoy',  # 👈 Replace this with your actual password
    database='world'
)

# %%
db

# %%
pd.read_sql_query('SELECT * FROM city',db).sample(10)
# Out:
# C:\Users\s\AppData\Local\Temp\ipykernel_16916\1457178850.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('SELECT * FROM city',db).sample(10)
#         ID        Name CountryCode             District  Population
# 2456  2457  AntsirabÃ©         MDG         Antananarivo      120239
# 803    804   Lapu-Lapu         PHL      Central Visayas      217019
# 2072  2073     Beipiao         CHN             Liaoning      194301
# 217    218    GoiÃ¢nia         BRA               GoiÃ¡s     1056330
# 2011  2012    Jiujiang         CHN              Jiangxi      291187
# 3082  3083      Bochum         DEU  Nordrhein-Westfalen      392830
# 3762  3763     Derbent         RUS             Dagestan       92300
# 3618  3619     Brjansk         RUS              Brjansk      457400
# ...

# %%
pd.read_sql_query('SELECT * FROM country',db)
# Out:
# C:\Users\s\AppData\Local\Temp\ipykernel_16916\421137779.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('SELECT * FROM country',db)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %%
pd.read_sql_query('SELECT * FROM city WHERE CountryCode LIKE "BRA"',db)
# Out:
# C:\Users\s\AppData\Local\Temp\ipykernel_16916\683784921.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('SELECT * FROM city WHERE CountryCode LIKE "BRA"',db)
#       ID                     Name CountryCode           District  Population
# 0    206               SÃ£o Paulo         BRA         SÃ£o Paulo     9968485
# 1    207           Rio de Janeiro         BRA     Rio de Janeiro     5598953
# 2    208                 Salvador         BRA              Bahia     2302832
# 3    209           Belo Horizonte         BRA       Minas Gerais     2139125
# 4    210                Fortaleza         BRA             CearÃ¡     2097757
# ..   ...                      ...         ...                ...         ...
# 245  451                 PalhoÃ§a         BRA     Santa Catarina       89465
# ...

# %% [markdown]
# ###### Qs. Find those country where people's LifeExpectancy is greater than 59.8

# %%
pd.read_sql_query('SELECT * FROM country WHERE LifeExpectancy > 59.8',db)
# Out:
# C:\Users\s\AppData\Local\Temp\ipykernel_16916\3837017788.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('SELECT * FROM country WHERE LifeExpectancy > 59.8',db)
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 163  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# ...

# %%
pd.read_sql_query('SELECT * FROM country',db)
